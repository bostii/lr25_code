# %%
from psana import *
import matplotlib.pyplot as plt
# %matplotlib nbagg
import sys
import numpy as np
sys.path.append('/reg/neh/home/sjarosch/LR25_Analysis/PythonRoutines')

# %%
run= 66
filename = "../lr25_code/npz/ana_intensity_scan_run_%d.npz" %run
arr = np.load(filename)

# %%
arr.keys()
# Out:
# ['His2d_centers',
#  'His2d_weights_val',
#  'His2d_weights_not_norm_vals',
#  'His2d_val']

# %%
plt.figure()
for num in range(3,9):
    plt.plot(arr[arr.keys()[0]][1],arr[arr.keys()[2]][num,:]/arr[arr.keys()[3]][num,:])
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
for pix in range(70):
    plt.plot(arr[arr.keys()[0]][0],arr[arr.keys()[2]][:,pix]/arr[arr.keys()[3]][:,pix])
# Out:
# <img src="data:image/png;base64,...">
