# %%
from psana import *
import numpy as np
import os
import matplotlib.pyplot as plt
from skbeam.core.accumulators.histogram import Histogram
# %matplotlib nbagg
folder = "/reg/d/psdm/AMO/amolr2516/results/npzfiles/run0065"
files = os.listdir(folder)

# %%
for nfi,fi in enumerate(files):
    f=np.load(os.path.join(folder,fi))
    if nfi==0:
        print "yep"
        gas_mean=np.nanmean(f['GasDetector'][:,0])
        gas_std=np.nanstd(f['GasDetector'][:,0])
        gas_max=np.nanmax(f['GasDetector'][:,0])
        His2d = Histogram((100/10,0,gas_max),(714/10,0,713))
        His2d_weights = Histogram((100/10,0,gas_max),(714/10,0,713))
        His2d_weights_not_norm = Histogram((100/10,0,gas_max),(714/10,0,713))
    for evt in range(len(f['GasDetector'][:,0])):
        His2d.fill(list(f['GasDetector'][evt,0]*np.ones(714)),range(714))
        values= list(np.nan_to_num(np.asarray(f['SHESwf'][evt,:])))
        His2d_weights.fill(list(f['GasDetector'][evt,0]*np.ones(714)),range(714),weights=values/f['GasDetector'][evt,0])
        His2d_weights_not_norm.fill(list(f['GasDetector'][evt,0]*np.ones(714)),range(714),weights=values)
# Out:
# yep

# %%
plt.figure()
num=200
plt.plot(His2d.centers[0],His2d_weights.values[:,::]/His2d.values[:,::])
plt.ylim(0,2000)
plt.xlim(0.2,0.8)
#His2d_weights.values
# Out:
# <img src="data:image/png;base64,...">
# (0.2, 0.8)

# %%
plt.figure()
plt.clf()
import matplotlib.pylab as pl
colors = pl.cm.jet(np.linspace(0,1,6))
counter = 0
for num in range(3,9):
    if num==0:
        continue
    plt.plot(His2d.centers[1],His2d_weights.values[num,:]/His2d.values[num,:],color =colors[counter])
    counter+=1
# Out:
# <img src="data:image/png;base64,...">

# %%
f.keys()
# Out:
# ['UXSpc',
#  'ITOF',
#  'GasDetector',
#  'TimeStamp',
#  'UXSwf',
#  'SHESHits',
#  'Pressure',
#  'SHESwf',
#  'EnvVar',
#  'EBeamParameters']

# %%
His2d.centers[0]
# Out:
# array([ 0.03356267,  0.07472609,  0.11588951,  0.15705293,  0.19821635,
#         0.23937977,  0.28054319,  0.32170661,  0.36287003,  0.40403345,
#         0.44519687,  0.48636029,  0.52752371,  0.56868713,  0.60985054,
#         0.65101396,  0.69217738,  0.7333408 ,  0.77450422,  0.81566764])

# %%
folder = "/reg/d/psdm/AMO/amolr2516/results/npzfiles/run0065"
files = os.listdir(folder)

# %%
len(files)
# Out:
# 32

# %%
f=np.load(os.path.join(folder,files[0]))

# %%
len(f['GasDetector'][:,0])
# Out:
# 2398

# %%
plt.figure()
plt.clf()
colors = pl.cm.jet(np.linspace(0,1,6))
counter = 0
for num in range(3,9):
    if num==0:
        continue
    plt.plot(His2d.centers[1],His2d_weights_not_norm.values[num,:]/His2d.values[num,:],color=colors[counter],label=str(His2d.centers[0][num]))
    counter+=1
plt.legend()
plt.xlabel('Energy (arb.)')
plt.ylabel('Counts')
gcf = plt.gcf()
gcf.savefig('run65_1.pdf', format='pdf', dpi=90)
# Out:
# <img src="data:image/png;base64,...">

# %%
pixs = [150,190,285,360,450]
fig = plt.figure()
ax = fig.add_subplot(111)
colors = pl.cm.jet(np.linspace(0,1,10))
counter = 1
for pix in pixs:
    val = np.argmin(abs(His2d.centers[1]-pix))
    print val
    ax.plot(His2d.centers[0],His2d_weights_not_norm.values[:,val]/His2d.values[:,val],label = counter)
    counter +=1
ax.legend(loc=2)
ax.set_xlabel('gas detector value')
ax.set_ylabel('Counts')

#gcf = plt.gcf()
#gcf.savefig('run65_2.pdf', format='pdf', dpi=90)
#His2d_weights.values
# Out:
# <img src="data:image/png;base64,...">
# 14
# 18
# 28
# 35
# 44

# %%
His2d.centers[0]
# Out:
# array([ 0.0429106 ,  0.12873179,  0.21455299,  0.30037419,  0.38619538,
#         0.47201658,  0.55783777,  0.64365897,  0.72948016,  0.81530136])
