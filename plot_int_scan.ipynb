# %%
from psana import *
import matplotlib.pyplot as plt
# %matplotlib nbagg
import sys
import numpy as np
sys.path.append('/reg/neh/home/sjarosch/LR25_Analysis/PythonRoutines')

# %%
run= 66
filename = "../lr25_code/npz/ana_intensity_scan_run_%d.npz" %run
arr = np.load(filename)

# %%
arr.keys()
# Out:
# ['His2d_centers',
#  'His2d_weights_val',
#  'His2d_weights_not_norm_vals',
#  'His2d_val']

# %%
import matplotlib.pylab as pl
plt.figure()
colors = pl.cm.jet(np.linspace(0,1,7))
ct = 0
for num in range(3,9):
    ct+=1
    minat = np.argmin(np.abs(arr[arr.keys()[0]][1]-412))
    values=arr[arr.keys()[2]][num,minat]/arr[arr.keys()[3]][num,minat]
    plt.plot(arr[arr.keys()[0]][1],arr[arr.keys()[2]][num,:]/arr[arr.keys()[3]][num,:]/values,label=arr[arr.keys()[0]][0][num],color =colors[ct])
plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
for pix in range(70):
    plt.plot(arr[arr.keys()[0]][0],arr[arr.keys()[2]][:,pix]/arr[arr.keys()[3]][:,pix])
# Out:
# <img src="data:image/png;base64,...">

# %%
np.argmin(np.abs(arr[arr.keys()[0]][1]-405))
# Out:
# 40
