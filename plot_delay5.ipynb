# %%
from psana import *
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
# %matplotlib nbagg
import sys
import numpy as np
sys.path.append('/reg/neh/home/sjarosch/LR25_Analysis/PythonRoutines')

# %%
import os
#calib_file = "calib_array_pass500_centre510_1.npy"  # data 
calib_file = "calibSHES_pixtoeV_run0104.npy"
calib_folder = "/reg/d/psdm/AMO/amolr2516/calib/SHES"
calib_SHES = np.load(os.path.join(calib_folder,calib_file))+3 #add three for last day (central for pass energy of 490)

# %%
def SUM(A,n):
    if n==1:
        return A.sum(axis=0)
    else:
        return SUM(A.sum(axis=0),(n-1))

def ratioSUM(A,B,n):
    return SUM(A,n)/SUM(B,n)

def ratioS(A,B,string,n):
    sum_A = eval("SUM(A%s,n)" %string)
    sum_B = eval("SUM(B%s,n)" %string)
    return sum_A/sum_B

# %%
run=178
plt.figure()
plt.title('gas detector values')

filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run
print filename
arr = np.load(filename)
His2d_centers= arr[arr.keys()[0]]
His2d_w= arr[arr.keys()[1]]
His2d = arr[arr.keys()[2]]
    
for ii in range(0,5):
    vals=ratioS(His2d_w,His2d,"[ii,:,:,:,:,:]",4)
    plt.plot(calib_SHES,vals,label=His2d_centers[0][ii])
    #plt.plot(calib_SHES,His2d_w_b[ii,:,:,:].sum(axis=0).sum(axis=0)/His2d_b[ii,:,:,:].sum(axis=0).sum(axis=0),label=His2d_centers_b[0][ii])
plt.legend()
# Out:
# <img src="data:image/png;base64,...">
# ../lr25_code/npz/ana_delay5_run_0178.npz

# %%
run=178
plt.figure()
plt.title('pump intensity')

filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run
arr = np.load(filename)
His2d_centers= arr[arr.keys()[0]]
His2d_w= arr[arr.keys()[1]]
His2d = arr[arr.keys()[2]]
    
for ii in range(0,5):
    vals=SUM(His2d_w[:,:,:,0:5,ii,:],4)\
             /SUM(His2d[:,:,:,0:5,ii,:],4)
    plt.plot(calib_SHES,vals,label=His2d_centers[4][ii])
    #plt.plot(calib_SHES,His2d_w_b[ii,:,:,:].sum(axis=0).sum(axis=0)/His2d_b[ii,:,:,:].sum(axis=0).sum(axis=0),label=His2d_centers_b[0][ii])
plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
run=178
plt.figure()
plt.title('probe intensity')

filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run
arr = np.load(filename)
His2d_centers= arr[arr.keys()[0]]
His2d_w= arr[arr.keys()[1]]
His2d = arr[arr.keys()[2]]
lookat="[:,:,:,ii,:,:]"    
looknr = 4
for ii in range(0,5):
    vals=ratioS(His2d_w,His2d,lookat,looknr)
    plt.plot(calib_SHES,vals,label=His2d_centers[3][ii])
    #plt.plot(calib_SHES,His2d_w_b[ii,:,:,:].sum(axis=0).sum(axis=0)/His2d_b[ii,:,:,:].sum(axis=0).sum(axis=0),label=His2d_centers_b[0][ii])
plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
run=178
plt.figure()
plt.title('probe intensity with fixed pump')

filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run
arr = np.load(filename)
His2d_centers= arr[arr.keys()[0]]
His2d_w= arr[arr.keys()[1]]
His2d = arr[arr.keys()[2]]

lookat="[:,:,:,ii,0,:]" 
looknr = 3
    
for ii in range(0,4):
    vals=ratioS(His2d_w,His2d,lookat,looknr)
    plt.plot(calib_SHES,vals,label=His2d_centers[3][ii])
    #plt.plot(calib_SHES,His2d_w_b[ii,:,:,:].sum(axis=0).sum(axis=0)/His2d_b[ii,:,:,:].sum(axis=0).sum(axis=0),label=His2d_centers_b[0][ii])
plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
run=178
plt.figure()
plt.title('pump intensity with fixed probe')

filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run
arr = np.load(filename)
His2d_centers= arr[arr.keys()[0]]
His2d_w= arr[arr.keys()[1]]
His2d = arr[arr.keys()[2]]

lookat="[:,:,:,0,ii,:]" 
looknr = 3
    
for ii in range(1,5):
    vals=ratioS(His2d_w,His2d,lookat,looknr)
    plt.plot(calib_SHES,vals,label=His2d_centers[3][ii])
    #plt.plot(calib_SHES,His2d_w_b[ii,:,:,:].sum(axis=0).sum(axis=0)/His2d_b[ii,:,:,:].sum(axis=0).sum(axis=0),label=His2d_centers_b[0][ii])
plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
#from pandas import rolling_mean as rm
from scipy.ndimage.filters import gaussian_filter as rm
avg = 5

run_background=178
runs= [189,182,186,177,180,185,191,188,192]
runs_delay=[-9,-6,-3,0,3,6,9,15,20]

plt.figure()
plt.title("background at -15")

lookat = "[:,:,:,:,:,:]"
lookatnr = 5

filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run_background
arr = np.load(filename)
background_centers= arr[arr.keys()[0]]
background_w= arr[arr.keys()[1]]
background_nr = arr[arr.keys()[2]]

background_vals = ratioS(background_w,background_nr,lookat,lookatnr)
colors = pl.cm.jet(np.linspace(0,1,len(runs_delay)+1))
for nr,run in enumerate(runs):
    filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run
    arr = np.load(filename)
    His2d_centers= arr[arr.keys()[0]]
    His2d_w= arr[arr.keys()[1]]
    His2d = arr[arr.keys()[2]]
    
    vals = ratioS(His2d_w,His2d,lookat,lookatnr)
    plt.plot(rm(calib_SHES,avg),rm(vals-background_vals,avg),label=runs_delay[nr],color=colors[nr])
plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
#from pandas import rolling_mean as rm
import matplotlib.cm as cm
from scipy.ndimage.filters import gaussian_filter as rm
avg = 2

run_background=178
runs= [189,182,186,177,180,185,191,188,192]
runs_delay=[-9,-6,-3,0,3,6,9,15,20]
#runs= [196,203,189,182,199,186,202,177,205,198,180,201,185,207,191,188,192,208]
#runs_delay=[-15,-12,-9,-6,-4,-3,-1,0,1,2,3,5,6,8,9,15,20,25]

plt.figure()
plt.title("background at -15")

lookat = "[1:,3,:,2:5,2:5,:]"
lookatnr = 4

filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run_background
arr = np.load(filename)
background_centers= arr[arr.keys()[0]]
background_w= arr[arr.keys()[1]]
background_nr = arr[arr.keys()[2]]

background_vals = ratioS(background_w,background_nr,lookat,lookatnr)
colors = pl.cm.jet(np.linspace(0,1,len(runs_delay)+1))
plot_arr = np.zeros((len(runs),len(background_vals)))
for nr,run in enumerate(runs):
    filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run
    arr = np.load(filename)
    His2d_centers= arr[arr.keys()[0]]
    His2d_w= arr[arr.keys()[1]]
    His2d = arr[arr.keys()[2]]
    plot_arr[nr,:]=rm(ratioS(His2d_w,His2d,lookat,lookatnr) - background_vals,avg)
plt.contourf(calib_SHES,np.array(runs_delay),plot_arr,vmin=-200,vmax=200,levels=np.arange(np.min(plot_arr),np.max(plot_arr),3),cm=cm.hot)
#plt.pcolormesh(calib_SHES,np.array(runs_delay),plot_arr)

plt.xlabel('energy [eV]')
plt.ylabel('delay in fs')
cbar=plt.colorbar()
plt.xlim(np.min(calib_SHES),np.max(calib_SHES))
plt.ylim(np.min(np.array(runs_delay)),np.max(np.array(runs_delay)))
#gcf = plt.gcf()
#gcf.savefig('delay_scan_140-171_bin_e1_540_600.pdf', format='pdf', dpi=90)
# Out:
# <img src="data:image/png;base64,...">
# (-9, 20)

# %%
His2d_centers[3][:]
# Out:
# array([ 18000.,  34000.,  50000.,  66000.,  82000.])

# %%
from pandas import rolling_mean as rm
#import matplotlib.cm as cm
from scipy.ndimage.filters import gaussian_filter as rm
avg =2

run_background=178
#runs= [189,182,186,177,180,185,191,188,192]
#runs_delay=[-9,-6,-3,0,3,6,9,15,20]
runs= [196,203,189,182,199,186,202,177,205,198,180,201,185,207,191,188,192,208]
runs_delay=[-15,-12,-9,-6,-4,-3,-1,0,1,2,3,5,6,8,9,15,20,25]

plt.figure()
plt.title("background at -15")

lookat = "[2:,0:8:,:,0:5,:]"
lookat_non_res = "[2:,8:10,:,:,0:5,:]"
lookatnr = 5
lookatnr_non_res = 5


filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run_background
arr = np.load(filename)
background_centers= arr[arr.keys()[0]]
background_w= arr[arr.keys()[1]]
background_nr = arr[arr.keys()[2]]

background = ratioS(background_w,background_nr,lookat,lookatnr)
background_non_res = ratioS(background_w,background_nr,lookat_non_res,lookatnr_non_res)
#colors = pl.cm.jet(np.linspace(0,1,len(runs_delay)+1))
plot_arr = np.zeros((len(runs),len(background_vals)))
for nr,run in enumerate(runs):
    filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run
    arr = np.load(filename)
    His2d_centers= arr[arr.keys()[0]]
    His2d_w= arr[arr.keys()[1]]
    His2d = arr[arr.keys()[2]]
    signal_non_res=ratioS(His2d_w,His2d,lookat_non_res,lookatnr_non_res)
    signal = ratioS(His2d_w,His2d,lookat,lookatnr)
    plot_arr[nr,:]=rm(signal- signal_non_res - background + background_non_res,avg)
    #plot_arr[nr,:]=ratioS(His2d_w,His2d,lookat,lookatnr)-background_vals
#plt.contourf(calib_SHES,np.array(runs_delay),plot_arr,vmin=-200,vmax=200,levels=np.arange(np.min(plot_arr),np.max(plot_arr),3),cm=cm.hot)
plt.pcolormesh(calib_SHES,np.array(runs_delay),plot_arr)
#plt.pcolormesh(plot_arr[:,350:400])


plt.xlabel('energy [eV]')
plt.ylabel('delay in fs')
cbar=plt.colorbar()
plt.xlim(np.min(calib_SHES),np.max(calib_SHES))
plt.ylim(np.min(np.array(runs_delay)),np.max(np.array(runs_delay)))
time_dep_signal=np.sum(plot_arr[:,350:390],axis=1)
#gcf = plt.gcf()
#gcf.savefig('delay_scan_140-171_bin_e1_540_600.pdf', format='pdf', dpi=90)7
# Out:
# <img src="data:image/png;base64,...">

# %%
SUM(His2d[2:,9:10,:,:,0:5,:],5)[0]
# Out:
# 689.0

# %%
plt.figure()
for ii in range(10):
    plt.scatter(ii,SUM(His2d[:,ii,:,:,:,0],4),30)
plt.ylim(-0,)
# Out:
# <img src="data:image/png;base64,...">
# (0, 12000.0)

# %%
#rom pandas import rolling_mean as rm
#import matplotlib.cm as cm
from scipy.ndimage.filters import gaussian_filter as rm
avg =2

run_background=196
#runs= [189,182,186,177,180,185,191,188,192]
#runs_delay=[-9,-6,-3,0,3,6,9,15,20]
runs= [196,178,203,189,182,199,186,202,177,205,198,180,201,185,207,191,188,192,208]
runs_delay=[-16,-15,-12,-9,-6,-4,-3,-1,0,1,2,3,5,6,8,9,15,20,25]

plt.figure()
plt.title("background at -15")

lookat = "[2:,0:6,:,3:5,0:5,:]"
lookat_non_res = "[2:,7:10,:,3:5,0:5,:]"
lookatnr = 5
lookatnr_non_res = 5


filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run_background
arr = np.load(filename)
background_centers= arr[arr.keys()[0]]
background_w= arr[arr.keys()[1]]
background_nr = arr[arr.keys()[2]]

background = rm(ratioS(background_w,background_nr,lookat,lookatnr),avg)
background_non_res = rm(ratioS(background_w,background_nr,lookat_non_res,lookatnr_non_res),avg)
#colors = pl.cm.jet(np.linspace(0,1,len(runs_delay)+1))
plot_arr = np.zeros((len(runs),len(background_vals)))
for nr,run in enumerate(runs):
    filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run
    arr = np.load(filename)
    His2d_centers= arr[arr.keys()[0]]
    His2d_w= arr[arr.keys()[1]]
    His2d = arr[arr.keys()[2]]
    signal_non_res=rm(ratioS(His2d_w,His2d,lookat_non_res,lookatnr_non_res),avg)
    signal = rm(ratioS(His2d_w,His2d,lookat,lookatnr),avg)
    #plot_arr[nr,:]=signal- signal_non_res - background + background_non_res
    plot_arr[nr,:]=signal-signal_non_res
#plt.contourf(calib_SHES,np.array(runs_delay),plot_arr,vmin=0,vmax=+900,levels=np.arange(np.min(plot_arr),np.max(plot_arr),3),cm=cm.hot)
plt.pcolormesh(calib_SHES,np.array(runs_delay),plot_arr)
#plt.pcolormesh(plot_arr)


plt.xlabel('energy [eV]')
plt.ylabel('delay in fs')
cbar=plt.colorbar()
plt.xlim(np.min(calib_SHES),np.max(calib_SHES))
plt.ylim(np.min(np.array(runs_delay)),np.max(np.array(runs_delay)))
time_dep_signal=np.sum(plot_arr[:,350:400],axis=1)
#gcf = plt.gcf()
#gcf.savefig('delay_scan_140-171_bin_e1_540_600.pdf', format='pdf', dpi=90)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.plot(np.array(runs_delay),time_dep_signal)
# Out:
# <img src="data:image/png;base64,...">

# %%
#from pandas import rolling_mean as rm
#import matplotlib.cm as cm
from scipy.ndimage.filters import gaussian_filter as rm
avg =3

run_background=196
#runs= [189,182,186,177,180,185,191,188,192]
#runs_delay=[-9,-6,-3,0,3,6,9,15,20]
runs= [196,178,203,189,182,199,186,202,177,205,198,180,201,185,207,191,188,192,208]
runs_delay=[-16,-15,-12,-9,-6,-4,-3,-1,0,1,2,3,5,6,8,9,15,20,25]

plt.figure()
plt.title("background at -15")

lookat = "[2:,0:8,:,3:5,:,:]"
lookat_non_res = "[2:,0:8,:,0:2,:,:]"
lookatnr = 5
lookatnr_non_res = 5


filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run_background
arr = np.load(filename)
background_centers= arr[arr.keys()[0]]
background_w= arr[arr.keys()[1]]
background_nr = arr[arr.keys()[2]]

background = rm(ratioS(background_w,background_nr,lookat,lookatnr),avg)
background_non_res = rm(ratioS(background_w,background_nr,lookat_non_res,lookatnr_non_res),avg)
#colors = pl.cm.jet(np.linspace(0,1,len(runs_delay)+1))
plot_arr = np.zeros((len(runs),len(background_vals)))
for nr,run in enumerate(runs):
    filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run
    arr = np.load(filename)
    His2d_centers= arr[arr.keys()[0]]
    His2d_w= arr[arr.keys()[1]]
    His2d = arr[arr.keys()[2]]
    signal_non_res=rm(ratioS(His2d_w,His2d,lookat_non_res,lookatnr_non_res),avg)
    signal = rm(ratioS(His2d_w,His2d,lookat,lookatnr),avg)
    plot_arr[nr,:]=signal- signal_non_res - background + background_non_res
    #plot_arr[nr,:]=signal-signal_non_res
plt.contourf(calib_SHES,np.array(runs_delay),plot_arr,vmin=-50,vmax=+90,levels=np.arange(np.min(plot_arr),np.max(plot_arr),3),cm=cm.hot)
#plt.pcolormesh(calib_SHES,np.array(runs_delay),plot_arr)
#plt.pcolormesh(plot_arr[:,385:400])


plt.xlabel('energy [eV]')
plt.ylabel('delay in fs')
cbar=plt.colorbar()
plt.xlim(np.min(calib_SHES),np.max(calib_SHES))
plt.ylim(np.min(np.array(runs_delay)),np.max(np.array(runs_delay)))
time_dep_signal=np.sum(plot_arr[:,385:400],axis=1)
#gcf = plt.gcf()
#gcf.savefig('delay_scan_140-171_bin_e1_540_600.pdf', format='pdf', dpi=90)
# Out:
# <img src="data:image/png;base64,...">

# %%
from pandas import rolling_mean as rm
#import matplotlib.cm as cm
from scipy.ndimage.filters import gaussian_filter as rm
avg =2

run_background=178
#runs= [189,182,186,177,180,185,191,188,192]
#runs_delay=[-9,-6,-3,0,3,6,9,15,20]
runs= [196,203,189,182,199,186,202,177,205,198,180,201,185,207,191,188,192,208]
runs_delay=[-15,-12,-9,-6,-4,-3,-1,0,1,2,3,5,6,8,9,15,20,25]

plt.figure()
plt.title("background at -15")

lookat = "[2:,0:8:,:,0:5,:]"
lookat_non_res = "[2:,8:10,:,:,0:5,:]"
lookatnr = 5
lookatnr_non_res = 5


filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run_background
arr = np.load(filename)
background_centers= arr[arr.keys()[0]]
background_w= arr[arr.keys()[1]]
background_nr = arr[arr.keys()[2]]





#background = ratioS(background_w,background_nr,lookat,lookatnr)
#background_non_res = ratioS(background_w,background_nr,lookat_non_res,lookatnr_non_res)
#colors = pl.cm.jet(np.linspace(0,1,len(runs_delay)+1))
plot_arr = np.zeros((len(runs),len(background_vals)))
for nr,run in enumerate(runs):
    filename = "../lr25_code/npz/ana_delay5_run_%04d.npz" %run
    arr = np.load(filename)
    His2d_centers= arr[arr.keys()[0]]
    His2d_w= arr[arr.keys()[1]]
    His2d = arr[arr.keys()[2]]
    signal_non_res=ratioS(His2d_w,His2d,lookat_non_res,lookatnr_non_res)
    signal = ratioS(His2d_w,His2d,lookat,lookatnr)
    plot_arr[nr,:]=rm(signal- signal_non_res - background + background_non_res,avg)
    #plot_arr[nr,:]=ratioS(His2d_w,His2d,lookat,lookatnr)-background_vals
#plt.contourf(calib_SHES,np.array(runs_delay),plot_arr,vmin=-200,vmax=200,levels=np.arange(np.min(plot_arr),np.max(plot_arr),3),cm=cm.hot)
plt.pcolormesh(calib_SHES,np.array(runs_delay),plot_arr)
#plt.pcolormesh(plot_arr[:,350:400])


plt.xlabel('energy [eV]')
plt.ylabel('delay in fs')
cbar=plt.colorbar()
plt.xlim(np.min(calib_SHES),np.max(calib_SHES))
plt.ylim(np.min(np.array(runs_delay)),np.max(np.array(runs_delay)))
time_dep_signal=np.sum(plot_arr[:,350:390],axis=1)
#gcf = plt.gcf()
#gcf.savefig('delay_scan_140-171_bin_e1_540_600.pdf', format='pdf', dpi=90)7
