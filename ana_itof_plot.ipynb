# %%
from psana import *
import matplotlib.pyplot as plt
# %matplotlib nbagg
import sys
import numpy as np
sys.path.append('/reg/neh/home/sjarosch/LR25_Analysis/PythonRoutines')

# %%
runs = [47,48,49,50]
fig = plt.figure()
for run in runs:
    filename = "../npz/ana_itof_run_%d.npz" %run
    arr = np.load(filename)
    plt.plot(arr[arr.keys()[0]],arr[arr.keys()[1]],label=run)
    plt.plot(arr[arr.keys()[0]],arr[arr.keys()[2]],label=str(run)+'un')
plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
runs = [42,52]
fig = plt.figure()
for run in runs:
    filename = "../npz/ana_itof_run_%d.npz" %run
    arr = np.load(filename)
    plt.plot(arr[arr.keys()[0]],arr[arr.keys()[1]],label=run)
    plt.plot(arr[arr.keys()[0]],arr[arr.keys()[2]],label=str(run)+'un')
plt.legend()
# Out:
# <img src="data:image/png;base64,...">
